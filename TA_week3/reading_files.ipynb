# %%
import pandas
read = pandas.read_csv("BreakingBad.csv")
read
# Out:
#     season  episode_number             title       airdate  rating  \
# 0        0               1  Live Free or Die  15 Jul. 2012     9.2
# 1        0               2          Madrigal  22 Jul. 2012     8.8
# 2        0               3        Hazard Pay  29 Jul. 2012     8.8
# 3        0               4         Fifty-One   5 Aug. 2012     8.8
# 4        0               5      Dead Freight  12 Aug. 2012     9.7
# ..     ...             ...               ...           ...     ...
# 73       5              12         Rabid Dog   1 Sep. 2013     9.1
# 74       5              13       To'hajiilee   8 Sep. 2013     9.8
# 75       5              14        Ozymandias  15 Sep. 2013    10.0
# 76       5              15     Granite State  22 Sep. 2013     9.6
# 77       5              16            Felina  29 Sep. 2013     9.9
#
#    total_votes                                               desc
# 0     (27,445)  Now that Gus is dead, Walt, Jesse, and Mike wo...
# ...
