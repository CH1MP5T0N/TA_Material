# %%
#Here we have a dataset that includes all of the breaking bad episodes and their ratings
import pandas as pd
df = pd.read_csv("breaking_bad.csv", encoding="latin-1")
df
# Out:
#          Date  Season  Episode                          Title  \
# 0   20-Jan-08       1        1                          Pilot
# 1   27-Jan-08       1        2            Cat's in the Bag...
# 2   10-Feb-08       1        3  ...And the Bag's in the River
# 3   17-Feb-08       1        4                     Cancer Man
# 4   24-Feb-08       1        5                    Gray Matter
# ..        ...     ...      ...                            ...
# 57  01-Sep-13       5       12                      Rabid Dog
# 58  08-Sep-13       5       13                    To'hajiilee
# 59  15-Sep-13       5       14                     Ozymandias
# 60  22-Sep-13       5       15                  Granite State
# 61  29-Sep-13       5       16                         Felina
#
#           Directed by                            Written by  Duration_mins  \
# 0      Vince Gilligan                        Vince Gilligan             58
# ...

# %% [markdown]
# Exercise 1: Please make a graph of any kind (bar, scatter, etc.) and plot the name of the episodes with their respective ratings

# %%
import matplotlib.pyplot as plt
plt.bar()
plt.bar(df["Title"], df["Rating_IMDB"], color="blue", width= 0.8)
# Out:
# <BarContainer object of 62 artists>

# %% [markdown]
# Exercise 2: Please sort the dataframe based on its duration

# %%
df.sort_values("Duration_mins", ascending=False)
# Out:
#          Date  Season  Episode              Title        Directed by  \
# 34  24-Jul-11       4        2  Thirty-Eight Snub  Michelle MacLaren
# 0   20-Jan-08       1        1              Pilot     Vince Gilligan
# 60  22-Sep-13       5       15      Granite State        Peter Gould
# 61  29-Sep-13       5       16             Felina     Vince Gilligan
# 45  09-Oct-11       4       13           Face Off     Vince Gilligan
# ..        ...     ...      ...                ...                ...
# 39  28-Aug-11       4        7        Problem Dog        Peter Gould
# 31  06-Jun-10       3       12      Half Measures     Adam Bernstein
# 8   15-Mar-09       2        2            Grilled       Charles Haid
# 43  25-Sep-11       4       11        Crawl Space       Scott Winant
# 46  15-Jul-12       5        1   Live Free or Die     Michael Slovis
#
#                                     Written by  Duration_mins  \
# 34              Vince Gilligan, George Mastras             60
# ...
